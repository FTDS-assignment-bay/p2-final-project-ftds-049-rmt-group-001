# %% [markdown]
# # Introduction

# %% [markdown]
# ----
#
# **Objectives** :  Notebook ini berisi proses Exploratory Data Analysis (EDA), text preprocessing, pembuatan model rekomendasi berbasis Word2Vec, serta evaluasi hasil rekomendasi. Pendekatan yang digunakan adalah content-based filtering dengan memanfaatkan teks ulasan pengguna.
#
# ----

# %% [markdown]
# # Import Libraries

# %%
# Core
import pandas as pd
import numpy as np
import random
import re

# NLP
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# Word Embedding
from gensim.models import Word2Vec

# Similarity
from sklearn.metrics.pairwise import cosine_similarity

# Visualization
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud

# Warning control
import warnings
warnings.filterwarnings("ignore")

# Download resource NLTK
nltk.download("punkt_tab")
nltk.download("stopwords")
# Out:
# [nltk_data] Downloading package punkt_tab to C:\Users\Ziko Ananda
# [nltk_data]     Setyawan\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package stopwords to C:\Users\Ziko Ananda
# [nltk_data]     Setyawan\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %% [markdown]
# # Data Loading

# %% [markdown]
# Pada project ini digunakan dua dataset:
# - `data_cleaned.csv` → data produk headset (product-level)
# - `review_data_cleaned.csv` → data ulasan pengguna (review-level)

# %%
df_product = pd.read_csv("./scrape_and_cleaning/data_cleaned.csv")
df_review = pd.read_csv("./scrape_and_cleaning/review_data_cleaned.csv")

# %%
df_review.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1008 entries, 0 to 1007
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   product        1008 non-null   object
#  1   brand          1008 non-null   object
#  2   review_text    1008 non-null   object
#  3   review_rating  1008 non-null   object
# dtypes: object(4)
# memory usage: 31.6+ KB

# %%
df_review.duplicated().sum()
# Out:
# 0

# %%
df_product.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 287 entries, 0 to 286
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   product        287 non-null    object
#  1   feature        287 non-null    object
#  2   brand          287 non-null    object
#  3   price          287 non-null    float64
#  4   rating         287 non-null    float64
#  5   color          287 non-null    object
#  6   ear_placement  287 non-null    object
#  7   form_factor    287 non-null    object
#  8   impedance      287 non-null    object
#  9   image_url      287 non-null    object
#  10  reviews        287 non-null    object
# dtypes: float64(2), object(9)
# memory usage: 24.8+ KB

# %%
df_product.duplicated().sum()
# Out:
# 0

# %%
df_review.head()
# Out:
#                                              product   brand  \
# 0  Baseus Eli Sport 2 Open-Ear Headphones Wireles...  Baseus
# 1  Baseus Eli Sport 2 Open-Ear Headphones Wireles...  Baseus
# 2  Baseus Eli Sport 2 Open-Ear Headphones Wireles...  Baseus
# 3  Baseus Eli Sport 2 Open-Ear Headphones Wireles...  Baseus
# 4  Baseus Eli Sport 2 Open-Ear Headphones Wireles...  Baseus
#
#                                          review_text       review_rating
# 0  I've got to be honest, I'm blown away by the s...  5.0 out of 5 stars
# 1  I'm a big fan of Baseus earbuds. These things ...  5.0 out of 5 stars
# 2  Product had great sound and comfort but did no...  4.0 out of 5 stars
# 3  This review is for Baseus Eli Sport 2 Open-ear...  3.0 out of 5 stars
# 4  Very reasonable. Loud and clear! I mostly wear...  5.0 out of 5 stars

# %%
# Extract Rating
df_review["review_rating"] = (
    df_review["review_rating"]
    .astype(str)
    .str.extract(r'(\d+(?:\.\d+)?)')[0]
    .astype(float)
)

# %%
# proses labelling
label=[]

for i in df_review['review_rating']:
    if i < 3 :
        label.append('Negative')
    elif i >3 :
        label.append('Positive')
    else: label.append('Neutral')

df_review['label']=label

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ## Distribusi Sentimen

# %%
eda = df_review.copy()

# %%
# Check Label Distribution
print(eda['label'].value_counts())
fig, ax = plt.subplots(figsize=(15,5))
sns.countplot(x = 'label',data= eda, palette='Set2')
plt.title('Sentiment Distribution')
plt.show()
# Out:
# label
# Positive    859
# Negative     95
# Neutral      54
# Name: count, dtype: int64

# %% [markdown]
# ## Jumlah Karakter Pada Review

# %%
eda["char_count"] = eda["review_text"].apply(len)
plt.figure(figsize=(15, 5))
sns.histplot(eda['char_count'], bins=50, kde=True, color='green')
plt.title('Distribution of Character Count')
plt.xlabel('Number of Character')
plt.ylabel('Frequency')
plt.show()

# %%
fig, axes = plt.subplots(1, 3, figsize=(15, 5), sharey=True)

sns.histplot(data=eda[eda['label'] == 'Positive'], x='char_count', bins=50, kde=True, ax=axes[0], color='red')
axes[0].set_title('Positive Review - Character Count')
axes[0].set_xlabel('Number of Character')
axes[0].set_ylabel('Frequency')

sns.histplot(data=eda[eda['label'] == 'Negative'], x='char_count', bins=50, kde=True, ax=axes[1])
axes[1].set_title('Negative Review - Character Count')
axes[1].set_xlabel('Number of Character')

sns.histplot(data=eda[eda['label'] == 'Neutral'], x='char_count', bins=50, kde=True, ax=axes[2], color ='yellow')
axes[2].set_title('Neutral Review - Character Count')
axes[2].set_xlabel('Number of Character')

plt.tight_layout()
plt.show()

# %%
stats_by_label = eda.groupby('label')['char_count'].agg(['min', 'max', 'mean'])
overall = eda['char_count'].agg(['min', 'max', 'mean'])

stats_by_label.loc['ALL'] = overall
display(stats_by_label)
# Out:
#           min     max        mean
# label
# Negative  9.0  2887.0  771.484211
# Neutral   4.0  2529.0  815.240741
# Positive  3.0  7022.0  817.292200
# ALL       3.0  7022.0  812.865079

# %% [markdown]
# ## Jumlah Kata Tiap Review

# %%
eda['word_count'] = eda['review_text'].astype(str).apply(lambda x: len(nltk.word_tokenize(x)))
plt.figure(figsize=(15, 5))
sns.histplot(eda['word_count'], bins=50, kde=True, color='green')
plt.title('Distribution of Words Count')
plt.xlabel('Number of Words')
plt.ylabel('Frequency')
plt.show()

# %%
fig, axes = plt.subplots(1, 3, figsize=(15, 5), sharey=True)

sns.histplot(data=eda[eda['label'] == 'Positive'], x='word_count', bins=50, kde=True, ax=axes[0], color='red')
axes[0].set_title('Positive Review - Words Count')
axes[0].set_xlabel('Number of Words')
axes[0].set_ylabel('Frequency')

sns.histplot(data=eda[eda['label'] == 'Negative'], x='word_count', bins=50, kde=True, ax=axes[1])
axes[1].set_title('Negative Review - Words Count')
axes[1].set_xlabel('Number of Words')

sns.histplot(data=eda[eda['label'] == 'Neutral'], x='word_count', bins=50, kde=True, ax=axes[2])
axes[2].set_title('Neutral Review - Words Count')
axes[2].set_xlabel('Number of Words')

plt.tight_layout()
plt.show()

# %%
stats_by_label = eda.groupby('label')['word_count'].agg(['min', 'max', 'mean'])
overall = eda['word_count'].agg(['min', 'max', 'mean'])

stats_by_label.loc['ALL'] = overall
display(stats_by_label)
# Out:
#           min     max        mean
# label
# Negative  2.0   595.0  159.915789
# Neutral   1.0   531.0  167.425926
# Positive  1.0  1439.0  169.385332
# ALL       1.0  1439.0  168.387897

# %% [markdown]
# ## WordCloud

# %%
# Membuat wordcloud
text_positive = eda[eda['label'] == 'Positive'].review_text.values
cloud_text_positive = WordCloud(background_color='black',colormap="cool",collocations=False,width=2000,height=1000).generate(" ".join(text_positive))

# Menampilkan wordcloud
plt.figure(figsize=(15,10))
plt.axis('off')
plt.title("Positive Review Words",fontsize=20)
plt.imshow(cloud_text_positive)

# %%
# Membuat wordcloud
text_negative = eda[eda['label'] == 'Negative'].review_text.values
cloud_text_negative = WordCloud(background_color='black',colormap="cool",collocations=False,width=2000,height=1000).generate(" ".join(text_negative))

# Menampilkan wordcloud
plt.figure(figsize=(15,10))
plt.axis('off')
plt.title("Negative Review Words",fontsize=20)
plt.imshow(cloud_text_negative)

# %%
# Membuat wordcloud
text_neutral = eda[eda['label'] == 'Neutral'].review_text.values
cloud_text_neutral = WordCloud(background_color='black',colormap="cool",collocations=False,width=2000,height=1000).generate(" ".join(text_neutral))

# Menampilkan wordcloud
plt.figure(figsize=(15,10))
plt.axis('off')
plt.title("Neutral Review Words",fontsize=20)
plt.imshow(cloud_text_neutral)

# %% [markdown]
# # Text Preprocessing

# %%
stop_words = set(stopwords.words("english"))

def preprocess_text(text):
    """
    Melakukan preprocessing teks untuk kebutuhan Word2Vec.

    Tujuan preprocessing ini BUKAN untuk klasifikasi,
    melainkan untuk menghasilkan token yang stabil
    dan bermakna secara semantik.

    Langkah:
    1. Lowercase
    2. Menghapus karakter non-huruf
    3. Tokenisasi
    4. Stopword removal
    5. Menghapus token terlalu pendek

    Parameters
    ----------
    text : str
        Teks review mentah.

    Returns
    -------
    List[str]
        Token bersih untuk Word2Vec.
    """
    if pd.isna(text):
        return []

    # Case folding
    text = text.lower()

    # Menghapus karakter selain huruf
    text = re.sub(r"[^a-z\s]", " ", text)

    # Merapikan spasi
    text = re.sub(r"\s+", " ", text).strip()

    # Tokenisasi
    tokens = word_tokenize(text)

    # Stopword removal + token pendek
    tokens = [
        token for token in tokens
        if token not in stop_words and len(token) > 2
    ]

    return tokens

# %%
df_review["token"] = df_review["review_text"].apply(preprocess_text)

# Optional: versi string (buat debugging / EDA)
df_review["clean_review"] = df_review["token"].apply(lambda x: " ".join(x))

# %% [markdown]
# # Merge Dataset

# %%
# Menggabungkan review dan metadata produk
df = df_review.merge(
    df_product,
    on="product",
    how="left"
)

df.head()
# Out:
#                                              product brand_x  \
# 0  Baseus Eli Sport 2 Open-Ear Headphones Wireles...  Baseus
# 1  Baseus Eli Sport 2 Open-Ear Headphones Wireles...  Baseus
# 2  Baseus Eli Sport 2 Open-Ear Headphones Wireles...  Baseus
# 3  Baseus Eli Sport 2 Open-Ear Headphones Wireles...  Baseus
# 4  Baseus Eli Sport 2 Open-Ear Headphones Wireles...  Baseus
#
#                                          review_text  review_rating     label  \
# 0  I've got to be honest, I'm blown away by the s...            5.0  Positive
# 1  I've got to be honest, I'm blown away by the s...            5.0  Positive
# 2  I've got to be honest, I'm blown away by the s...            5.0  Positive
# 3  I'm a big fan of Baseus earbuds. These things ...            5.0  Positive
# 4  I'm a big fan of Baseus earbuds. These things ...            5.0  Positive
#
#                                                token  \
# 0  [got, honest, blown, away, sound, quality, che...
# ...

# %%
# Drop kolom duplikat yang tidak dipakai 
df = df.drop(columns=["brand_x"]) 
# Rename kolom agar konsisten 
df = df.rename(columns={"brand_y": "brand"}) 
df.head()
# Out:
#                                              product  \
# 0  Baseus Eli Sport 2 Open-Ear Headphones Wireles...
# 1  Baseus Eli Sport 2 Open-Ear Headphones Wireles...
# 2  Baseus Eli Sport 2 Open-Ear Headphones Wireles...
# 3  Baseus Eli Sport 2 Open-Ear Headphones Wireles...
# 4  Baseus Eli Sport 2 Open-Ear Headphones Wireles...
#
#                                          review_text  review_rating     label  \
# 0  I've got to be honest, I'm blown away by the s...            5.0  Positive
# 1  I've got to be honest, I'm blown away by the s...            5.0  Positive
# 2  I've got to be honest, I'm blown away by the s...            5.0  Positive
# 3  I'm a big fan of Baseus earbuds. These things ...            5.0  Positive
# 4  I'm a big fan of Baseus earbuds. These things ...            5.0  Positive
#
#                                                token  \
# 0  [got, honest, blown, away, sound, quality, che...
# 1  [got, honest, blown, away, sound, quality, che...
# ...

# %% [markdown]
# # Modeling

# %%
# Set seed supaya hasil konsisten 
SEED = 42
random.seed(SEED)
np.random.seed(SEED)

# Training Word2Vec
w2v_model = Word2Vec(
    sentences=df["token"],   # List of token list
    vector_size=100,         # Dimensi embedding
    window=5,                # Konteks kiri-kanan
    min_count=2,             # Buang kata sangat jarang
    workers=4,
    sg=1,                    # Skip-gram → semantic similarity
    seed=SEED
)

print("Word2Vec model trained")
print("Vocabulary size:", len(w2v_model.wv))
# Out:
# Word2Vec model trained
# Vocabulary size: 5186

# %%
def get_sentence_vector(tokens, model):
    """
    Mengubah satu kalimat (list token)
    menjadi satu vektor representatif
    dengan cara rata-rata Word2Vec embedding.

    Jika tidak ada token yang dikenal model,
    kembalikan vektor nol.

    Parameters
    ----------
    tokens : List[str]
    model : Word2Vec

    Returns
    -------
    np.ndarray
        Vektor representasi kalimat.
    """
    vectors = [model.wv[t] for t in tokens if t in model.wv]
    if not vectors:
        return np.zeros(model.vector_size)
    return np.mean(vectors, axis=0)

# %%
def vectorize_query(query, model):
    """
    Mengubah input user menjadi vektor Word2Vec.

    Parameters
    ----------
    query : str
        Query pengguna.
    model : Word2Vec

    Returns
    -------
    np.ndarray
        Vektor query.
    """
    tokens = preprocess_text(query)
    return get_sentence_vector(tokens, model)

# %%
def recommend_products(
    query,
    brand=None,
    max_price=None,
    top_n=3
):
    """
    Menghasilkan rekomendasi produk berdasarkan
    kemiripan semantik antara query dan review.

    Parameters
    ----------
    query : str
        Keyword pengguna.
    brand : str, optional
        Filter brand.
    max_price : float, optional
        Filter harga maksimum.
    top_n : int
        Jumlah produk direkomendasikan.

    Returns
    -------
    top_products : pd.DataFrame
        Produk unik dengan similarity tertinggi.
    df_sim : pd.DataFrame
        Semua review beserta similarity score.
    """
    query_vector = vectorize_query(query, w2v_model)

    df_sim = df.copy()

    # HITUNG VECTOR DI SINI (ON THE FLY)
    df_sim["review_vector"] = df_sim["token"].apply(
        lambda x: get_sentence_vector(x, w2v_model)
    )

    df_sim["similarity"] = df_sim["review_vector"].apply(
        lambda x: cosine_similarity([query_vector], [x])[0][0]
    )

    if brand:
        df_sim = df_sim[df_sim["brand"].str.lower() == brand.lower()]

    if max_price:
        df_sim = df_sim[df_sim["price"] <= max_price]

    # buang smartwatch
    df_sim = df_sim[
        ~df_sim["product"].str.contains("watch|smartwatch", case=False, na=False)
    ]

    top_products = (
        df_sim
        .sort_values("similarity", ascending=False)
        .drop_duplicates("product")
        .head(top_n)
    )

    return top_products, df_sim

# %%
def get_top_reviews(product_name, df_sim, n=3):
    """
    Mengambil N review paling relevan
    untuk satu produk tertentu.
    """
    reviews = (
        df_sim[
            (df_sim["product"] == product_name) &
            (df_sim["label"] == "Positive")
        ]
        .drop_duplicates("review_text")
        .sort_values("similarity", ascending=False)
    )
    return reviews.head(n)

# %%
def clean_for_display(text):
    """
    Khusus untuk tampilan UI.
    TIDAK dipakai model.
    """
    if not isinstance(text, str):
        return ""

    # gabungkan char-per-char
    text = text.replace("\n", " ")

    # rapikan spasi
    text = re.sub(r"\s+", " ", text)

    # potong blok huruf tunggal beruntun
    text = re.sub(r"(?:\b[A-Za-z]\b\s+){10,}", "", text)

    return text.strip()

# %%
def format_recommendation(top_products, df_sim):
    lines = []
    lines.append("Top 3 Produk Headset Berdasarkan Review:\n")

    for idx, row in enumerate(top_products.itertuples(), start=1):
        lines.append(
            f"{idx}. Product: {row.product}\n"
            f"   Brand: {row.brand}\n"
            f"   Price: {row.price}\n"
            f"   Rating: {row.rating}\n"
            f"   Relevance: {row.similarity:.4f}\n"
            f"   Top Reviews:"
        )

        top_reviews = get_top_reviews(row.product, df_sim)

        for _, r in top_reviews.iterrows():
            clean_text = clean_for_display(r.review_text)
            lines.append(
                f"   - ({r.label}) {clean_text[:180]}..."
            )

        lines.append("")

    return "\n".join(lines)

# %%
query = "headset low latency microphone directional sound"

top_products, df_sim = recommend_products(
    query=query,
    max_price=100,
    top_n=3
)

print(format_recommendation(top_products, df_sim))
# Out:
# Top 3 Produk Headset Berdasarkan Review:
#
# 1. Product: XIAOMI Redmi Buds 4 Active
#    Brand: Xiaomi
#    Price: 30.74
#    Rating: 4.3
#    Relevance: 0.9049
#    Top Reviews:
#    - (Positive) I recently purchased the Xiaomi Redmi Buds 4 Active for my wife and myself, and I am extremely impressed with their performance! The sound quality is exceptional, with crisp highs ...
#    - (Positive) I recently purchased the Xiaomi Redmi Buds 4 Active and I’m absolutely impressed with them. For the price, they deliver exceptional sound quality, comfort, and functionality that I...
#    - (Positive) I had previously been using truck stop earbuds (several different types), and they are all terrible. When I bought this item I was like "I like my other Xiaomi products, let's try ...
#
# 2. Product: Redmi Buds 6 Lite in-Ear Headphones
#    Brand: Xiaomi
#    Price: 26.75
#    Rating: 4.4
#    Relevance: 0.9001
#    Top Reviews:
# ...

# %% [markdown]
# # Model Evaluation

# %% [markdown]
# ## Inter-Review Cosine Similarity

# %%
df["review_vector"] = df["token"].apply( lambda x: get_sentence_vector(x, w2v_model))
# Ambil sample review vector
sample_vectors = np.vstack(df["review_vector"].values[:200])

# Hitung similarity matrix
sim_matrix = cosine_similarity(sample_vectors)

# Ambil similarity antar review yang BERBEDA (off-diagonal)
off_diag_similarities = sim_matrix[np.triu_indices_from(sim_matrix, k=1)]

print("Mean inter-review similarity:", np.mean(off_diag_similarities))
print("Std inter-review similarity:", np.std(off_diag_similarities))
# Out:
# Mean inter-review similarity: 0.9185674
# Std inter-review similarity: 0.06903978

# %% [markdown]
# Analisis Inter-Review Similarity
#
# Untuk mengecek kualitas embedding Word2Vec, dilakukan pengukuran inter-review cosine similarity yaitu tingkat kemiripan antar vektor review yang berbeda.
#
# Hasil Evaluasi
# - **Mean inter-review similarity:** 0.9188
# - **Standar deviasi:** 0.0706
#
# Nilai similarity yang cukup tinggi menunjukkan bahwa banyak review memiliki representasi vektor yang berdekatan, karena sebagian besar review membahas topik yang sama, yaitu produk headset/audio.
#
# Tingginya similarity dipengaruhi oleh:
# - Dataset yang berada dalam domain yang homogen
# - Penggunaan rata-rata embedding (mean pooling) yang meratakan perbedaan kata
# - Sifat Word2Vec yang tidak memodelkan struktur kalimat secara eksplisit
#
# Akibatnya, embedding mampu menangkap **konteks umum domain** namun kurang sensitif terhadap perbedaan semantik yang lebih spesifik antar review.

# %% [markdown]
# ## Zero Vector Ratio

# %%
zero_vector_ratio = np.mean(
    [np.all(vec == 0) for vec in df["review_vector"]]
)

print("Zero vector ratio:", zero_vector_ratio)
# Out:
# Zero vector ratio: 0.002170374389582203

# %% [markdown]
# Analisis
# Zero vector ratio menunjukkan proporsi review yang setelah preprocessing tidak memiliki satu pun token yang dikenal oleh model Word2Vec.
# Artinya review tersebut direpresentasikan sebagai vektor nol.
#
# Nilai 0.2% berarti:
# - Hampir seluruh review memiliki representasi semantik
# - Vocabulary Word2Vec cukup kaya
# - Preprocessing tidak terlalu agresif
#
# Interpretasi
# Nilai ini tergolong sangat baik.
# Zero vector ratio yang rendah menandakan bahwa model mampu menangkap makna teks pada mayoritas data dan tidak kehilangan informasi penting selama preprocessing.

# %%
def evaluate_coverage(queries, df, top_n=3):
    recommended_products = set()

    for q in queries:
        top_products, _ = recommend_products(q, top_n=top_n)
        recommended_products.update(top_products["product"].tolist())

    coverage = len(recommended_products) / df["product"].nunique()
    return coverage


test_queries = [
    "gaming headset",
    "noise cancelling",
    "long battery life",
    "cheap wireless earbuds",
    "microphone clear voice"
]

coverage_score = evaluate_coverage(test_queries, df)
print("Product coverage:", coverage_score)
# Out:
# Product coverage: 0.07738095238095238

# %% [markdown]
# ## Coverage Produk

# %% [markdown]
# Analisis
# Product coverage mengukur persentase produk unik yang pernah muncul sebagai rekomendasi dari seluruh produk yang tersedia.
#
# Nilai ~8% berarti:
# - Model cenderung fokus pada subset produk yang paling relevan secara semantik
# - Sistem tidak merekomendasikan produk secara acak
# - Ada kecenderungan bias ke produk dengan review yang informatif
#
# Interpretasi
# Untuk sistem content-based recommendation, coverage pada rentang 5–15% masih dianggap wajar.
# Coverage yang terlalu tinggi justru sering mengindikasikan rekomendasi yang kurang selektif.
# Dengan kata lain Model ini lebih mementingkan relevansi daripada eksplorasi

# %%
query = "gaming headset low latency microphone"

top_products, df_sim = recommend_products(query, top_n=3)

print(format_recommendation(top_products, df_sim))
# Out:
# Top 3 Produk Headset Berdasarkan Review:
#
# 1. Product: Sennheiser Momentum Sport
#    Brand: Sennheiser
#    Price: 149.95
#    Rating: 3.5
#    Relevance: 0.8993
#    Top Reviews:
#    - (Positive) Fits well with my large ears (usually need a large or XL silicone tip to make isolation work).They are decently flush, do not sick out far. I appreciate the custom tip and wing siz...
#    - (Positive) Great sound. Stays in ear. Good price....
#
# 2. Product: Wireless Earbuds
#    Brand: Rinsmola
#    Price: 8.49
#    Rating: 4.3
#    Relevance: 0.8922
#    Top Reviews:
#    - (Positive) The headphones shown in the image are the Fhumsh Wireless Headphones. These in-ear earbuds are popular on Amazon for their value and features such as Bluetooth 5.3 or higher connec...
#    - (Positive) For someone hard-of-hearing like myself, these are the answer to my prayers. Didn't have to spend a boatload of money, either. Frankly, I don't know how they can sell them so reaso...
# ...

# %% [markdown]
# Observasi
# - Produk yang direkomendasikan sesuai dengan konteks query (audio, latency, microphone)
# - Review yang ditampilkan relevan dengan kata kunci
# - Model mampu mengaitkan deskripsi teknis query dengan pengalaman pengguna
#
# Catatan
# - Beberapa review yang ditampilkan masih duplikat
# - Ini bukan kesalahan model Word2Vec, melainkan heuristik pemilihan top review
#
# Interpretasi
# Secara semantik, model bekerja dengan baik.
# Perbaikan yang diperlukan bersifat post-processing / UX, bukan perombakan model.

# %% [markdown]
# # Kesimpulan

# %% [markdown]
# **Conclusion**
#
# Model rekomendasi headset berbasis Word2Vec dan cosine similarity yang dibangun pada proyek ini dapat dikategorikan sebagai:
# - Unsupervised learning
# - Content-based recommender system
# - Layak digunakan sebagai prototype atau demo aplikasi rekomendasi
#
# Model ini memanfaatkan review pengguna untuk mencocokkan kebutuhan (query) dengan produk yang relevan secara semantik, tanpa bergantung pada label eksplisit atau aturan berbasis keyword.
#
# **Kelebihan utama model**:
# - Mampu menangkap relevansi berdasarkan makna, bukan sekadar kecocokan kata
# - Tidak memerlukan data berlabel untuk training
# - Fleksibel terhadap input query bebas dari pengguna
#
# **Keterbatasan model**:
# - Representasi kalimat menggunakan rata-rata embedding membuat model kurang sensitif terhadap perbedaan detail makna
# - Ranking produk masih murni berdasarkan similarity tanpa mempertimbangkan personalisasi pengguna
# - Model belum mendukung eksplorasi produk baru secara adaptif
#
# Secara keseluruhan, model ini valid secara metodologi dan sesuai dengan tujuan proyek sebagai sistem rekomendasi berbasis intent. Pendekatan yang digunakan cukup efektif untuk konteks akademik dan demonstrasi aplikasi, dengan ruang pengembangan lebih lanjut pada aspek representasi semantik, evaluasi, dan personalisasi.

# %% [markdown]
# # Model Saving

# %%
# Simpan model Word2Vec ke file
w2v_model.save("w2v_headset_model.model")
print("Word2Vec model saved as w2v_headset_model.model")

# Pilih kolom yang benar-benar dibutuhkan saat inference
df_final = df[
    [
        "product",
        "brand",
        "price",
        "rating",
        "review_text",
        "label",
        "image_url",
        "token"
    ]
]
print("Final dataframe saved as df_final.csv")
df_final.to_csv("df_final.csv", index=False)
# Out:
# Word2Vec model saved as w2v_headset_model.model
# Final dataframe saved as df_final.csv
