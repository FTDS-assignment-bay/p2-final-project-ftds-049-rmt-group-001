# %% [markdown]
# # i. Introduction

# %% [markdown]
# Program ini dikembangkan untuk melakukan tahapan data cleaning dan preprocessing pada dataset hasil web scraping produk __TWS__ dari E-Commerce __Amazon__. Tahapan yang dilakukan mencakup normalisasi nama kolom, imputasi missing values sesuai dengan tipe data, konversi tipe data kolom _price_ dan _rating_ ke format numerik, serta ekstraksi informasi fitur produk ke dalam kolom __feature__ melalui pemisahan teks pada kolom __product_name__.
#
# Tahapan data cleaning ini bertujuan untuk memastikan data memiliki kualitas yang baik, konsistensi format, serta kompatibilitas terhadap proses analisis statistik dan pemodelan data selanjutnya.

# %% [markdown]
# # ii. Import Libraries

# %%
# Import Libraries
import json
import pandas as pd
import numpy as np
import re
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # iii. Data Loading

# %%
#read json file
with open('soundcore.json') as f1, open('bose.json') as f2, open('baseus.json') as f3, open('jbl.json') as f4, open('sennheiser.json') as f5, open('realme.json') as f6, open('huawei.json') as f7, open('jbl.json') as f8, open('xiaomi.json') as f9:
    data1 = json.load(f1)
    data2 = json.load(f2)
    data3 = json.load(f3)
    data4 = json.load(f4)
    data5 = json.load(f5)
    data6 = json.load(f6)
    data7 = json.load(f7)
    data8 = json.load(f8)
    data9 = json.load(f9)

#combine all data
data = data1 + data2 + data3 + data4 + data5 + data6 + data7 + data8 + data9

#save combined data to json file
with open("all_data.json", "w") as review_json:
    json.dump(data, review_json, indent=2, ensure_ascii=True)

# %%
# Read JSON file into DataFrame
with open('all_data.json') as f:
    data = json.load(f)

df = pd.DataFrame(data)
df
# Out:
#                                           product_name              rating  \
# 0    Soundcore P30i by Anker Noise Cancelling Earbu...  4.4 out of 5 stars
# 1    Soundcore P30i by Anker Noise Cancelling Earbu...  4.4 out of 5 stars
# 2    Soundcore P30i by Anker Noise Cancelling Earbu...  4.4 out of 5 stars
# 3    Soundcore P30i by Anker Noise Cancelling Earbu...  4.4 out of 5 stars
# 4    Soundcore P30i by Anker Noise Cancelling Earbu...  4.4 out of 5 stars
# ..                                                 ...                 ...
# 709  JBL Tune Buds - True wireless Noise Cancelling...  4.2 out of 5 stars
# 710  realme Air 6 Pro True Wireless Earbuds, 50dB N...  4.4 out of 5 stars
# 711  realme Air 6 Pro True Wireless Earbuds, 50dB N...  4.4 out of 5 stars
# 712  realme Buds Air 6 Pro True Wireless Earbuds, 5...  4.4 out of 5 stars
# 713  Soundcore P40i by Anker, Noise Cancelling Wire...  4.3 out of 5 stars
#
#       price      brand        color ear_placement form_factor impedance  \
# 0    $29.99  Soundcore        Black        In Ear      In Ear   16 Ohms
# 1    $29.99  Soundcore        Black        In Ear      In Ear   16 Ohms
# 2     $7.79  Soundcore         Blue        In Ear      In Ear   16 Ohms
# 3     $7.59  Soundcore        Green        In Ear      In Ear   16 Ohms
# 4    $29.99  Soundcore         Pink        In Ear      In Ear   16 Ohms
# ..      ...        ...          ...           ...         ...       ...
# 709  $59.95        JBL        Black        In Ear      In Ear   32 Ohms
# 710  $87.82     realme         Grey        In Ear      In Ear       N/A
# 711  $87.82     realme         Grey        In Ear      In Ear       N/A
# 712  $84.99     realme  Silver Blue        In Ear      In Ear  1.4 Ohms
# 713  $34.99  Soundcore        Black        In Ear      In Ear   14 Ohms
#
#                                              image_url  \
# 0    https://m.media-amazon.com/images/I/51HbL1WS+K...
# 1    https://m.media-amazon.com/images/I/51HbL1WS+K...
# 2    https://m.media-amazon.com/images/I/41Quiz3Dg-...
# 3    https://m.media-amazon.com/images/I/51013C6va8...
# 4    https://m.media-amazon.com/images/I/41KMo8Ldy8...
# ..                                                 ...
# 709  https://m.media-amazon.com/images/I/51EZig0rEA...
# 710  https://m.media-amazon.com/images/I/61Ktz5wyEw...
# 711  https://m.media-amazon.com/images/I/61Ktz5wyEw...
# 712  https://m.media-amazon.com/images/I/61e3G6oLxj...
# 713  https://m.media-amazon.com/images/I/61e9Npl3up...
#
#                                                reviews
# 0    [{'review': 'I had a pair of the AirPod Pros f...
# 1    [{'review': 'I had a pair of the AirPod Pros f...
# 2    [{'review': 'I had a pair of the AirPod Pros f...
# 3    [{'review': 'I had a pair of the AirPod Pros f...
# 4    [{'review': 'I had a pair of the AirPod Pros f...
# ..                                                 ...
# 709  [{'review': 'Very comfortable, decent noise ca...
# 710  [{'review': 'ConThe only bad part about these ...
# 711  [{'review': 'ConThe only bad part about these ...
# 712  [{'review': 'Amazing sound. The app was wonky ...
# 713  [{'review': 'I got these as a lower-cost repla...
#
# [714 rows x 10 columns]

# %%
# Save to CSV as backup
df.to_csv('data_before_clean.csv', index=False)

# %%
# Display DataFrame info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 714 entries, 0 to 713
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   product_name   714 non-null    object
#  1   rating         714 non-null    object
#  2   price          714 non-null    object
#  3   brand          714 non-null    object
#  4   color          714 non-null    object
#  5   ear_placement  714 non-null    object
#  6   form_factor    714 non-null    object
#  7   impedance      714 non-null    object
#  8   image_url      714 non-null    object
#  9   reviews        714 non-null    object
# dtypes: object(10)
# memory usage: 55.9+ KB

# %% [markdown]
# # iii. Data Cleaning

# %%
# Capitalize First Letter in Brand Column
df['brand'] = df['brand'].str.title()

# %%
# Drop Missing Value in Brand Column
df['brand'] = df['brand'].replace('N/A', None)
df = df.dropna(subset=['brand'])

# %%
# Sort DataFrame by Brand
df = df.sort_values(by='brand')

df
# Out:
#                                           product_name              rating  \
# 270  Baseus Eli 2i Fit Open-Ear Headphones, 8.8g Se...  4.4 out of 5 stars
# 225  Baseus E20 True Wireless Earbuds, 12mm Drivers...  4.6 out of 5 stars
# 226  Baseus BS1 NC Semi-in-Ear Noise Cancelling Ear...  4.3 out of 5 stars
# 227  Baseus Bass BS1 NC Semi-in-Ear True Wireless N...  4.3 out of 5 stars
# 228  Baseus Bass BP1 Pro Noise Cancelling Wireless ...  4.3 out of 5 stars
# ..                                                 ...                 ...
# 595  Xiaomi Redmi Buds 6 Active Wireles Earbuds (Gl...  4.2 out of 5 stars
# 596  XIAOMI TWSEJ04LS Redmi Airdots Earphones, Blue...  4.2 out of 5 stars
# 597  Xiaomi Sound Packet Mi Portable Bluetooth 5.4 ...  4.7 out of 5 stars
# 599  Xiaomi Wireless Earbuds Redmi Buds 3 Lite, Wir...  4.2 out of 5 stars
# 579  Redmi Buds 6 Lite in-Ear Headphones, Dynamic 4...  4.4 out of 5 stars
#
#       price   brand       color ear_placement form_factor impedance  \
# 270  $15.99  Baseus       Black      Open Ear    Open Ear   16 Ohms
# 225  $15.99  Baseus       White        In Ear      In Ear       N/A
# 226  $21.99  Baseus       Black        In Ear      In Ear   16 Ohms
# 227  $39.89  Baseus       White        In Ear      In Ear   16 Ohms
# 228  $27.99  Baseus  Ocean Blue        In Ear      In Ear       N/A
# ..      ...     ...         ...           ...         ...       ...
# 595  $24.99  Xiaomi       White        In Ear      In Ear   16 Ohms
# 596  $23.45  Xiaomi       Black        In Ear      In Ear   16 Ohms
# 597  $25.99  Xiaomi         N/A           N/A         N/A       N/A
# 599  $17.89  Xiaomi       White        In Ear      In Ear   70 Ohms
# 579  $21.70  Xiaomi       Black        In Ear      In Ear   32 Ohms
#
#                                              image_url  \
# 270  https://m.media-amazon.com/images/I/51XnDCIDaF...
# 225  https://m.media-amazon.com/images/I/51q9mJAXJj...
# 226  https://m.media-amazon.com/images/I/51V95ukJfM...
# 227  https://m.media-amazon.com/images/I/41a41P57iZ...
# 228  https://m.media-amazon.com/images/I/41SsqSVMpT...
# ..                                                 ...
# 595  https://m.media-amazon.com/images/I/41rWEasz8i...
# 596  https://m.media-amazon.com/images/I/61KDNdskQJ...
# 597  https://m.media-amazon.com/images/I/71oM-ntW-+...
# 599  https://m.media-amazon.com/images/I/31L0-uMto2...
# 579  https://m.media-amazon.com/images/I/61pzQJFZBA...
#
#                                                reviews
# 270  [{'review': 'These are actually surprisingly n...
# 225  [{'review': 'I am seriously impressed with the...
# 226  [{'review': 'absolutely amazing! Clear sound q...
# 227  [{'review': 'absolutely amazing! Clear sound q...
# 228  [{'review': 'Have you ever felt the gut rumbli...
# ..                                                 ...
# 595  [{'review': 'Muy bien.', 'rating': '5.0 out of...
# 596  [{'review': '¡Excelente!', 'rating': '5.0 out ...
# 597  [{'review': 'El pedido llegó en excelentes con...
# 599  [{'review': 'Todo en bien estado', 'rating': '...
# 579  [{'review': 'Is good quality for less money. I...
#
# [707 rows x 10 columns]

# %%
# Split Product Name into Product and Feature

df[['product', 'feature']] = (
    df['product_name']
    .str.split(r',|\||\s[-–—]\s', n=1, expand=True)
)

df['product'] = df['product'].str.strip()
df['feature'] = df['feature'].fillna('N/A').str.strip()

# Drop kolom awal
df.drop(columns=['product_name'], inplace=True)

df
# Out:
#                  rating   price   brand       color ear_placement form_factor  \
# 270  4.4 out of 5 stars  $15.99  Baseus       Black      Open Ear    Open Ear
# 225  4.6 out of 5 stars  $15.99  Baseus       White        In Ear      In Ear
# 226  4.3 out of 5 stars  $21.99  Baseus       Black        In Ear      In Ear
# 227  4.3 out of 5 stars  $39.89  Baseus       White        In Ear      In Ear
# 228  4.3 out of 5 stars  $27.99  Baseus  Ocean Blue        In Ear      In Ear
# ..                  ...     ...     ...         ...           ...         ...
# 595  4.2 out of 5 stars  $24.99  Xiaomi       White        In Ear      In Ear
# 596  4.2 out of 5 stars  $23.45  Xiaomi       Black        In Ear      In Ear
# 597  4.7 out of 5 stars  $25.99  Xiaomi         N/A           N/A         N/A
# 599  4.2 out of 5 stars  $17.89  Xiaomi       White        In Ear      In Ear
# 579  4.4 out of 5 stars  $21.70  Xiaomi       Black        In Ear      In Ear
#
#     impedance                                          image_url  \
# 270   16 Ohms  https://m.media-amazon.com/images/I/51XnDCIDaF...
# 225       N/A  https://m.media-amazon.com/images/I/51q9mJAXJj...
# 226   16 Ohms  https://m.media-amazon.com/images/I/51V95ukJfM...
# 227   16 Ohms  https://m.media-amazon.com/images/I/41a41P57iZ...
# 228       N/A  https://m.media-amazon.com/images/I/41SsqSVMpT...
# ..        ...                                                ...
# 595   16 Ohms  https://m.media-amazon.com/images/I/41rWEasz8i...
# 596   16 Ohms  https://m.media-amazon.com/images/I/61KDNdskQJ...
# 597       N/A  https://m.media-amazon.com/images/I/71oM-ntW-+...
# 599   70 Ohms  https://m.media-amazon.com/images/I/31L0-uMto2...
# 579   32 Ohms  https://m.media-amazon.com/images/I/61pzQJFZBA...
#
#                                                reviews  \
# 270  [{'review': 'These are actually surprisingly n...
# 225  [{'review': 'I am seriously impressed with the...
# 226  [{'review': 'absolutely amazing! Clear sound q...
# 227  [{'review': 'absolutely amazing! Clear sound q...
# 228  [{'review': 'Have you ever felt the gut rumbli...
# ..                                                 ...
# 595  [{'review': 'Muy bien.', 'rating': '5.0 out of...
# 596  [{'review': '¡Excelente!', 'rating': '5.0 out ...
# 597  [{'review': 'El pedido llegó en excelentes con...
# 599  [{'review': 'Todo en bien estado', 'rating': '...
# 579  [{'review': 'Is good quality for less money. I...
#
#                                                product  \
# 270              Baseus Eli 2i Fit Open-Ear Headphones
# 225                   Baseus E20 True Wireless Earbuds
# 226  Baseus BS1 NC Semi-in-Ear Noise Cancelling Ear...
# 227  Baseus Bass BS1 NC Semi-in-Ear True Wireless N...
# 228  Baseus Bass BP1 Pro Noise Cancelling Wireless ...
# ..                                                 ...
# 595  Xiaomi Redmi Buds 6 Active Wireles Earbuds (Gl...
# 596           XIAOMI TWSEJ04LS Redmi Airdots Earphones
# 597  Xiaomi Sound Packet Mi Portable Bluetooth 5.4 ...
# 599          Xiaomi Wireless Earbuds Redmi Buds 3 Lite
# 579                Redmi Buds 6 Lite in-Ear Headphones
#
#                                                feature
# 270  8.8g Secure Fit, 36H Battery, BassUp Technolog...
# 225  12mm Drivers with Powerful Bass, 33H Long Play...
# 226  No Ear Pressure, Hi-Res Audio (LDAC), 40H Play...
# 227  Hi-Res Audio (LDAC), 40H Playtime, 4g Ultra-Li...
# 228  Real-Time Adaptive Noise Cancelling, Adaptive ...
# ..                                                 ...
# 595  Bluetooth 5.4 in-Ear Headphones, 30H Long Batt...
# 596  Bluetooth, Sweatproof, True Wireless Earbuds, ...
# 597  IP67 Waterproof Outdoor Bluetooth Speaker with...
# 599  Wireless Earphones Bluetooth 5.2 Latency Stere...
# 579  Dynamic 40dB Active Noise Cancellation, up to ...
#
# [707 rows x 11 columns]

# %%
# Reorder columns
df = df[['product', 'feature', 'brand', 'price', 'rating', 'color', 'ear_placement', 'form_factor', 'impedance', 'image_url', 'reviews']]

df
# Out:
#                                                product  \
# 270              Baseus Eli 2i Fit Open-Ear Headphones
# 225                   Baseus E20 True Wireless Earbuds
# 226  Baseus BS1 NC Semi-in-Ear Noise Cancelling Ear...
# 227  Baseus Bass BS1 NC Semi-in-Ear True Wireless N...
# 228  Baseus Bass BP1 Pro Noise Cancelling Wireless ...
# ..                                                 ...
# 595  Xiaomi Redmi Buds 6 Active Wireles Earbuds (Gl...
# 596           XIAOMI TWSEJ04LS Redmi Airdots Earphones
# 597  Xiaomi Sound Packet Mi Portable Bluetooth 5.4 ...
# 599          Xiaomi Wireless Earbuds Redmi Buds 3 Lite
# 579                Redmi Buds 6 Lite in-Ear Headphones
#
#                                                feature   brand   price  \
# 270  8.8g Secure Fit, 36H Battery, BassUp Technolog...  Baseus  $15.99
# 225  12mm Drivers with Powerful Bass, 33H Long Play...  Baseus  $15.99
# 226  No Ear Pressure, Hi-Res Audio (LDAC), 40H Play...  Baseus  $21.99
# 227  Hi-Res Audio (LDAC), 40H Playtime, 4g Ultra-Li...  Baseus  $39.89
# 228  Real-Time Adaptive Noise Cancelling, Adaptive ...  Baseus  $27.99
# ..                                                 ...     ...     ...
# 595  Bluetooth 5.4 in-Ear Headphones, 30H Long Batt...  Xiaomi  $24.99
# 596  Bluetooth, Sweatproof, True Wireless Earbuds, ...  Xiaomi  $23.45
# 597  IP67 Waterproof Outdoor Bluetooth Speaker with...  Xiaomi  $25.99
# 599  Wireless Earphones Bluetooth 5.2 Latency Stere...  Xiaomi  $17.89
# 579  Dynamic 40dB Active Noise Cancellation, up to ...  Xiaomi  $21.70
#
#                  rating       color ear_placement form_factor impedance  \
# 270  4.4 out of 5 stars       Black      Open Ear    Open Ear   16 Ohms
# 225  4.6 out of 5 stars       White        In Ear      In Ear       N/A
# 226  4.3 out of 5 stars       Black        In Ear      In Ear   16 Ohms
# 227  4.3 out of 5 stars       White        In Ear      In Ear   16 Ohms
# 228  4.3 out of 5 stars  Ocean Blue        In Ear      In Ear       N/A
# ..                  ...         ...           ...         ...       ...
# 595  4.2 out of 5 stars       White        In Ear      In Ear   16 Ohms
# 596  4.2 out of 5 stars       Black        In Ear      In Ear   16 Ohms
# 597  4.7 out of 5 stars         N/A           N/A         N/A       N/A
# 599  4.2 out of 5 stars       White        In Ear      In Ear   70 Ohms
# 579  4.4 out of 5 stars       Black        In Ear      In Ear   32 Ohms
#
#                                              image_url  \
# 270  https://m.media-amazon.com/images/I/51XnDCIDaF...
# 225  https://m.media-amazon.com/images/I/51q9mJAXJj...
# 226  https://m.media-amazon.com/images/I/51V95ukJfM...
# 227  https://m.media-amazon.com/images/I/41a41P57iZ...
# 228  https://m.media-amazon.com/images/I/41SsqSVMpT...
# ..                                                 ...
# 595  https://m.media-amazon.com/images/I/41rWEasz8i...
# 596  https://m.media-amazon.com/images/I/61KDNdskQJ...
# 597  https://m.media-amazon.com/images/I/71oM-ntW-+...
# 599  https://m.media-amazon.com/images/I/31L0-uMto2...
# 579  https://m.media-amazon.com/images/I/61pzQJFZBA...
#
#                                                reviews
# 270  [{'review': 'These are actually surprisingly n...
# 225  [{'review': 'I am seriously impressed with the...
# 226  [{'review': 'absolutely amazing! Clear sound q...
# 227  [{'review': 'absolutely amazing! Clear sound q...
# 228  [{'review': 'Have you ever felt the gut rumbli...
# ..                                                 ...
# 595  [{'review': 'Muy bien.', 'rating': '5.0 out of...
# 596  [{'review': '¡Excelente!', 'rating': '5.0 out ...
# 597  [{'review': 'El pedido llegó en excelentes con...
# 599  [{'review': 'Todo en bien estado', 'rating': '...
# 579  [{'review': 'Is good quality for less money. I...
#
# [707 rows x 11 columns]

# %%
# Change price to numeric
df['price'] = (
    df['price']
    .astype(str)
    .str.replace(r'[$,]', '', regex=True)
)

df['price'] = pd.to_numeric(df['price'], errors='coerce')

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 707 entries, 270 to 579
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   product        707 non-null    object
#  1   feature        707 non-null    object
#  2   brand          707 non-null    object
#  3   price          707 non-null    float64
#  4   rating         707 non-null    object
#  5   color          707 non-null    object
#  6   ear_placement  707 non-null    object
#  7   form_factor    707 non-null    object
#  8   impedance      707 non-null    object
#  9   image_url      707 non-null    object
#  10  reviews        707 non-null    object
# dtypes: float64(1), object(10)
# memory usage: 66.3+ KB

# %%
df['product'].unique()
# Out:
# array(['Baseus Eli 2i Fit Open-Ear Headphones',
#        'Baseus E20 True Wireless Earbuds',
#        'Baseus BS1 NC Semi-in-Ear Noise Cancelling Earbuds with Adaptive Hybrid ANC',
#        'Baseus Bass BS1 NC Semi-in-Ear True Wireless Noise Cancelling Earbuds with Adaptive Hybrid ANC',
#        'Baseus Bass BP1 Pro Noise Cancelling Wireless Earbuds',
#        'Baseus Inspire XP1 Adaptive Noise Cancelling Earbuds',
#        'Baseus Inspire XC1 Open Ear Clip-On Earbuds',
#        'Baseus Eli Sport 2 Open-Ear Headphones Wireless Earbuds',
#        'Baseus Bowie MC1 Open Ear Clip-On Earbuds',
#        'Baseus Bowie MC1 Pro Open Ear Earbuds',
#        'Baseus Bowie 30 Max Active Noise Cancelling Headphones',
#        'Baseus Bass BC1 Open Ear Earbuds Clip-On Headphones',
#        'Baseus Bass BP1 NC Hybrid Active Noise Cancelling Wireless Earbuds',
#        'Baseus Bowie MC1 Pro Open Ear Clip-On Headphones',
#        'Baseus Inspire XH1 Adaptive Active Noise Cancelling Headphones',
#        'Bose Ultra Open Earbuds', 'Bose QuietComfort Headphones',
#        'Bose QuietComfort II In-Ear True Wireless Earbuds',
#        'Bose New QuietComfort Ultra Earbuds (2nd Gen)',
#        'Bose QuietComfort Ultra Bluetooth Earbuds',
#        'Bose QuietComfort Earbuds',
#        'Bose QuietComfort Noise Cancelling Earbuds-Bluetooth Wireless Earphones',
#        'Bose QuietComfort Earbuds II',
#        'Bose QuietComfort Ultra True Wireless Noise Cancelling In-Ear Earbuds',
#        'Bose QuietComfort Bluetooth Earbuds',
#        'Bose QuietComfort Ultra Wireless Earbuds',
#        'Bose QuietComfort Bluetooth Headphones',
#        'CMF Buds Pro 2 Wireless Earbuds with Smart Dial',
#        'CMF Buds 2a Wireless Earbuds 2025 New Active Noise Cancelling 42dB Hybrid ANC Bluetooth Headphones',
#        'Wireless Earbuds',
#        'Hybrid Active Noise Cancelling Ear Buds Wireless Earbuds Bluetooth Headphones with 80H Playback Wireless Charging Case & Dual LED Display Over Ear Hooks Earphones for Sports Running Gym Workout Black',
#        'HUAWEI FreeBuds 6 Earbuds', 'HUAWEI FreeBuds SE 3 Earphones',
#        'JBL Endurance Race 2', 'JBL Vibe Beam', 'JBL Vibe Beam 2',
#        'JBL Tour Pro 3', 'JBL Tune 230NC TWS', 'JBL Tune Flex 2',
#        'JBL Tune Flex', 'JBL Live Pro 2', 'JBL Quantum TWS AIR',
#        'JBL Vibe Buds', 'JBL Endurance Peak 3',
#        'JBL Quantum TWS True Wireless Noise Cancelling Gaming Earbuds',
#        'JBL Endurance Race TWS', 'JBL Live Beam 3', 'JBL VIBE 100 TWS',
#        'JBL Quantum TWS',
#        'JBL Tune 130NC TWS True Wireless In-Ear Noise Cancelling Headphones',
#        'JBL Tune Buds', 'JBL Tune Buds 2',
#        'JBL Vibe 100 TWS True Wireless In-Ear Headphones w/Charging Case',
#        'JBL Live PRO+ TWS True Wireless in-Ear Noise Cancelling Bluetooth Headphones',
#        'JBL LIVE PRO+ TWS True Wireless In-ear Noise Cancelling Bluetooth Headphones',
#        'JBL Tour PRO+ TWS True Wireless Bluetooth Earbuds',
#        'JLab Go Air Pop+ True Wireless Earbuds',
#        'JLab Go Air Pop+ Tones True Wireless Earbuds',
#        'JLab Go Air Tones+ True Wireless Earbuds Designed with Auto On and Connect',
#        'LEEMC Wireless Earbuds',
#        'Lenovo TWS Earbuds Yoga PC Edition Cosmic Blue Active Noise Cancellation Bluetooth 5.3 Wireless Earbuds ENC 3-Mic Clear Calls AI EQ Mode Switch for Gaming',
#        'Lenovo TWS Earbuds Yoga PC Edition Tidal Teal Active Noise Cancellation Bluetooth 5.3 Wireless Earbuds ENC 3-Mic Clear Calls AI EQ Mode Switch for Gaming',
#        'Monster Clarity 101 AirLinks Wireless Earbuds',
#        'realme Buds T300 Truly Wireless in-Ear Earbuds with 30dB ANC',
#        'realme Earbud T300',
#        'realme Buds Wireless 5 ANC in Ear Bluetooth Headphones',
#        'realme Air 6 True Wireless Earbuds',
#        'realme Air 7 True Wireless Earbuds',
#        'realme Buds Air 7 Pro with Ai Live Translation',
#        'Realme Air 7 True Wireless Earbuds',
#        'realme Air 6 Pro True Wireless Earbuds',
#        'realme Buds Air 6 Pro True Wireless Earbuds',
#        'realme T110 AI ENC Noise Cancelling Wireless Earbuds',
#        'realme Buds T310 Truly Wireless in-Ear Earbuds with 46dB Hybrid ANC',
#        'realme Buds Air 7', 'Sennheiser ACCENTUM True Wireless Earbuds',
#        'Sennheiser Consumer Audio CX True Wireless Earbuds',
#        'Sennheiser Consumer Audio MOMENTUM True Wireless 3 Earbuds Bluetooth In-Ear Headphones for Music and Call with ANC',
#        'Sennheiser Consumer Audio MOMENTUM True Wireless 3 Earbuds -Bluetooth In-Ear Headphones for Music and Calls with ANC',
#        'Sennheiser Consumer Audio MOMENTUM True Wireless 3 Earbuds -Bluetooth In-Ear Headphones for Music',
#        'Sennheiser Momentum 4 Wireless Noise Cancelling Headphones',
#        'Sennheiser Accentum True Wireless In-Ear Headphones (Blue)',
#        'Sennheiser Momentum True Wireless 4 Smart Earbuds',
#        'Sennheiser Momentum Sport',
#        'Sennheiser ACCENTUM Open Wireless Earbuds',
#        'Sennheiser Consumer Audio CX Plus True Wireless Special Edition',
#        'Sennheiser MOMENTUM 4 Wireless Noise Cancelling Headphones',
#        'Sennheiser Momentum True Wireless 4 Smart Earbuds with Bluetooth 5.4',
#        'Sennheiser MOMENTUM True Wireless 4 Black Copper',
#        'Sennheiser MOMENTUM True Wireless 4 Smart Earbuds',
#        'Sennheiser MOMENTUM True Wireless 4 Smart Earbuds with Bluetooth 5.4',
#        'Sennheiser Consumer Audio Sport True Wireless Earbuds',
#        'Sennheiser Momentum True Wireless in-Ear Headphones (M3IETW/Black)',
#        'for Huawei Honor 30 Pro Wireless Earbuds Bluetooth 5.3 Headphones with Charging Case',
#        'Skullcandy Method 360 ANC Wireless Earbuds',
#        'Skullcandy Dime Evo Wireless Earbuds',
#        'Sony WF-C510 Truly Wireless in-Ear Bluetooth Earbud Headphones with up to 22-Hour Battery',
#        'Soundcore P40i by Anker',
#        'Soundcore P30i by Anker Noise Cancelling Earbuds',
#        'Soundcore P31i by Anker', 'Soundcore Liberty Buds by Anker',
#        'Soundcore by Anker Life A1 True Wireless Earbuds',
#        'Soundcore by Anker A20i True Wireless Earbuds',
#        'Soundcore by Anker P20i True Wireless Earbuds',
#        'Soundcore Sleep A30 by Anker Sleep Earbuds',
#        'Soundcore by Anker Space A40 Auto-Adjustable Active Noise Cancelling Wireless Earbuds',
#        'Soundcore by Anker Space A40 Adaptive Active Noise Cancelling Wireless Earbuds',
#        'soundcore by Anker Space A40 Auto-Adjustable Active Noise Cancelling Wireless Earbuds',
#        'Soundcore Sport X20 by Anker', 'Soundcore Liberty 4 Pro by Anker',
#        'Soundcore AeroClip by Anker',
#        'soundcore Sleep A30 by Anker Sleep Earbuds',
#        'Soundcore by Anker Liberty 4 NC Wireless Earbuds',
#        'soundcore by Anker Liberty 4 NC Wireless Noise Cancelling Earbuds',
#        'Soundcore by Anker Liberty 4 NC Noise Cancelling Earbuds',
#        'soundcore Sport X20 by Anker',
#        'Soundcore V20i by Anker Open-Ear Headphones',
#        'Soundcore by Anker Life P2 Mini True Wireless Earbuds',
#        'Soundcore Select 4 Go Bluetooth Shower Speaker by Anker',
#        'TOZO T10 Wireless Earbuds Bluetooth 5.3 Headphones',
#        'TOZO Wireless Earbuds Build in Mic Clear Calls Ergonomic Light Weight Bluetooth 5.3 in Ear Headphones Waterproof Premium Stereo Sound Ear Buds 30H Playtime with 32 EQs via APP',
#        'TOZO Wireless Earbuds Bluetooth 5.3 Headphones Premium Sound Performance Touch Control LED Digital Display Wireless Charging Case Earphones Black',
#        'TWS Earbuds ENC Noise Cancellation Wireless Bluetooth Earphones',
#        'Xiaomi Redmi Buds 6 Play',
#        'XIAOMI Redmi Buds 6 Active Wireles Earbuds (Global Version)',
#        'XIAOMI Redmi Watch 5 Active',
#        'Xiaomi Redmi Buds 6 (Global Version) TWS Earphone',
#        'Xiaomi Redmi Buds 6 Active Wireles Earbuds (Global Version)',
#        'Xiaomi Redmi Buds 6 Dual Mic Fast Pair LDAC',
#        'Xiaomi Portable Mini Bluetooth Speaker Sound Pocket',
#        'XIAOMI Redmi Buds 6 Pro',
#        'Xiaomi Redmi Buds Essential Wireless Earbuds M2222E1',
#        'Xiaomi Redmi Buds 5 Pro (Global Version) Wireless Earbuds',
#        'XIAOMI Redmi Buds 4 Active TWS Wireless Earbuds',
#        'XIAOMI Redmi Buds 4 Active',
#        'Xiaomi Redmi Buds 4 Lite TWS Wireless Earbuds',
#        'XIAOMI Redmi Buds 5 Wireless Earphone',
#        'Xiaomi Redmi Buds 5 Wireless Earphone',
#        'XIAOMI Redmi Watch 5 Active Smartwatch',
#        'XIAOMI Portable Bluetooth Speaker Bluetooth 5.4',
#        'XIAOMI Redmi Buds 6 Dual Mic Fast Pair LDAC',
#        'Xiaomi Redmi Buds 4 Active', 'XIAOMI Redmi Buds 6 Active',
#        'XIAOMI OpenWear Stereo Hi-Res LHDC Earbuds', 'Redmi Buds 6 Lite',
#        'Redmi Buds 6 Lite in-Ear Headphones',
#        'XIAOMI Redmi Buds 4 Lite TWS Wireless Earbuds',
#        'XIAOMI TWSEJ04LS Redmi Airdots Earphones',
#        'Xiaomi Sound Packet Mi Portable Bluetooth 5.4 Speaker',
#        'Xiaomi Wireless Earbuds Redmi Buds 3 Lite'], dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 707 entries, 270 to 579
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   product        707 non-null    object
#  1   feature        707 non-null    object
#  2   brand          707 non-null    object
#  3   price          707 non-null    float64
#  4   rating         707 non-null    object
#  5   color          707 non-null    object
#  6   ear_placement  707 non-null    object
#  7   form_factor    707 non-null    object
#  8   impedance      707 non-null    object
#  9   image_url      707 non-null    object
#  10  reviews        707 non-null    object
# dtypes: float64(1), object(10)
# memory usage: 66.3+ KB

# %%
# Check Rating Column
df.rating.value_counts()
# Out:
# rating
# 4.2 out of 5 stars    140
# 4.4 out of 5 stars    116
# 4.3 out of 5 stars    116
# 4.0 out of 5 stars     91
# 4.1 out of 5 stars     86
# 4.6 out of 5 stars     42
# 3.8 out of 5 stars     31
# 3.9 out of 5 stars     15
# 4.7 out of 5 stars     13
# 3.7 out of 5 stars     11
# 4.5 out of 5 stars     10
# 3.6 out of 5 stars     10
# 4.9 out of 5 stars      9
# 3.2 out of 5 stars      7
# 4.8 out of 5 stars      4
# 5.0 out of 5 stars      3
# 3.5 out of 5 stars      3
# Name: count, dtype: int64

# %% [markdown]
# Rating masih bersifat object sehingga harus mengubahnya menjadi tipe data float dengan cara mengambil angka pertama saja

# %%
# Rating to numeric
df['rating'] = pd.to_numeric(
    df['rating'].astype(str).str.extract(r'(\d+\.\d+)')[0],
    errors='coerce'
)

df.rating.value_counts()
# Out:
# rating
# 4.2    140
# 4.4    116
# 4.3    116
# 4.0     91
# 4.1     86
# 4.6     42
# 3.8     31
# 3.9     15
# 4.7     13
# 3.7     11
# 4.5     10
# 3.6     10
# 4.9      9
# 3.2      7
# 4.8      4
# 5.0      3
# 3.5      3
# Name: count, dtype: int64

# %% [markdown]
# # iv. Handle Missing Value

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 707 entries, 270 to 579
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   product        707 non-null    object
#  1   feature        707 non-null    object
#  2   brand          707 non-null    object
#  3   price          707 non-null    float64
#  4   rating         707 non-null    float64
#  5   color          707 non-null    object
#  6   ear_placement  707 non-null    object
#  7   form_factor    707 non-null    object
#  8   impedance      707 non-null    object
#  9   image_url      707 non-null    object
#  10  reviews        707 non-null    object
# dtypes: float64(2), object(9)
# memory usage: 66.3+ KB

# %% [markdown]
# Jika dilihat dari df.info data tidak memiliki nilai null, tetapi saat scraping jika menemukan missing value akan diubah menjadi N/A sehingga tidak terbaca sebagai missing value pada df.info. Sehingga dibutuhkan untuk mengubah nilai N/A  pada masing masing kolom menjadi nan

# %%
# Change feature 'N/A' to NaN
df['feature'] = df['feature'].replace('N/A', np.nan)

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 707 entries, 270 to 579
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   product        707 non-null    object
#  1   feature        691 non-null    object
#  2   brand          707 non-null    object
#  3   price          707 non-null    float64
#  4   rating         707 non-null    float64
#  5   color          707 non-null    object
#  6   ear_placement  707 non-null    object
#  7   form_factor    707 non-null    object
#  8   impedance      707 non-null    object
#  9   image_url      707 non-null    object
#  10  reviews        707 non-null    object
# dtypes: float64(2), object(9)
# memory usage: 66.3+ KB

# %%
# Change brand 'N/A' to NaN
df['brand'] = df['brand'].replace('N/A', np.nan)

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 707 entries, 270 to 579
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   product        707 non-null    object
#  1   feature        691 non-null    object
#  2   brand          707 non-null    object
#  3   price          707 non-null    float64
#  4   rating         707 non-null    float64
#  5   color          707 non-null    object
#  6   ear_placement  707 non-null    object
#  7   form_factor    707 non-null    object
#  8   impedance      707 non-null    object
#  9   image_url      707 non-null    object
#  10  reviews        707 non-null    object
# dtypes: float64(2), object(9)
# memory usage: 66.3+ KB

# %%
# Change color 'N/A' to NaN
df['color'] = df['color'].replace('N/A', np.nan)

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 707 entries, 270 to 579
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   product        707 non-null    object
#  1   feature        691 non-null    object
#  2   brand          707 non-null    object
#  3   price          707 non-null    float64
#  4   rating         707 non-null    float64
#  5   color          697 non-null    object
#  6   ear_placement  707 non-null    object
#  7   form_factor    707 non-null    object
#  8   impedance      707 non-null    object
#  9   image_url      707 non-null    object
#  10  reviews        707 non-null    object
# dtypes: float64(2), object(9)
# memory usage: 66.3+ KB

# %%
# Change ear_placement'N/A' to NaN
df['ear_placement'] = df['ear_placement'].replace('N/A', np.nan)

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 707 entries, 270 to 579
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   product        707 non-null    object
#  1   feature        691 non-null    object
#  2   brand          707 non-null    object
#  3   price          707 non-null    float64
#  4   rating         707 non-null    float64
#  5   color          697 non-null    object
#  6   ear_placement  695 non-null    object
#  7   form_factor    707 non-null    object
#  8   impedance      707 non-null    object
#  9   image_url      707 non-null    object
#  10  reviews        707 non-null    object
# dtypes: float64(2), object(9)
# memory usage: 66.3+ KB

# %%
# Change form_factor 'N/A' to NaN
df['form_factor'] = df['form_factor'].replace('N/A', np.nan)

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 707 entries, 270 to 579
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   product        707 non-null    object
#  1   feature        691 non-null    object
#  2   brand          707 non-null    object
#  3   price          707 non-null    float64
#  4   rating         707 non-null    float64
#  5   color          697 non-null    object
#  6   ear_placement  695 non-null    object
#  7   form_factor    696 non-null    object
#  8   impedance      707 non-null    object
#  9   image_url      707 non-null    object
#  10  reviews        707 non-null    object
# dtypes: float64(2), object(9)
# memory usage: 66.3+ KB

# %%
# Change impedance 'N/A' to NaN
df['impedance'] = df['impedance'].replace('N/A', np.nan)

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 707 entries, 270 to 579
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   product        707 non-null    object
#  1   feature        691 non-null    object
#  2   brand          707 non-null    object
#  3   price          707 non-null    float64
#  4   rating         707 non-null    float64
#  5   color          697 non-null    object
#  6   ear_placement  695 non-null    object
#  7   form_factor    696 non-null    object
#  8   impedance      510 non-null    object
#  9   image_url      707 non-null    object
#  10  reviews        707 non-null    object
# dtypes: float64(2), object(9)
# memory usage: 66.3+ KB

# %%
# Change image_url 'N/A' to NaN
df['image_url'] = df['image_url'].replace('N/A', np.nan)

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 707 entries, 270 to 579
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   product        707 non-null    object
#  1   feature        691 non-null    object
#  2   brand          707 non-null    object
#  3   price          707 non-null    float64
#  4   rating         707 non-null    float64
#  5   color          697 non-null    object
#  6   ear_placement  695 non-null    object
#  7   form_factor    696 non-null    object
#  8   impedance      510 non-null    object
#  9   image_url      707 non-null    object
#  10  reviews        707 non-null    object
# dtypes: float64(2), object(9)
# memory usage: 66.3+ KB

# %% [markdown]
# ## a. Imputation

# %% [markdown]
# Pada kolom price dan rating tidak memiliki null values tetapi akan tetap dilakukan handle missing value dengan imputasi menggunakan median sedangkan pada kolom feature, color, dan ear_placement akan diisi dengan nilai 'Unkown' menimbang bahwa missing value tidak terlalu banyak dan impedance akan diisi sebagai Not Specified, menjadi variable baru dikarenakan jika dilakukan dengan imputasi mode akan mempengaruhi data

# %%
# Numerik
df['price'] = df['price'].fillna(df['price'].median())
df['rating'] = df['rating'].fillna(df['rating'].median())

# Kategorikal
df['feature'] = df['feature'].fillna('N/A')
df['color'] = df['color'].fillna('Unknown')
df['ear_placement'] = df['ear_placement'].fillna('Unknown')
df['form_factor'] = df['form_factor'].fillna(df['form_factor'].mode()[0])
df['impedance'] = df['impedance'].fillna('Not Specified')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 707 entries, 270 to 579
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   product        707 non-null    object
#  1   feature        707 non-null    object
#  2   brand          707 non-null    object
#  3   price          707 non-null    float64
#  4   rating         707 non-null    float64
#  5   color          707 non-null    object
#  6   ear_placement  707 non-null    object
#  7   form_factor    707 non-null    object
#  8   impedance      707 non-null    object
#  9   image_url      707 non-null    object
#  10  reviews        707 non-null    object
# dtypes: float64(2), object(9)
# memory usage: 66.3+ KB

# %% [markdown]
# # v. Review Data Frame

# %% [markdown]
# Membuat review data frame dengan memisahkan product, brand dan reviews yang akan digunakan pada NLP model

# %%
# Explode reviews into separate rows
review_df = (
    df[['product', 'brand', 'reviews']]
    .explode('reviews')
)

review_df['review_text'] = review_df['reviews'].apply(lambda x: x['review'])
review_df['review_rating'] = review_df['reviews'].apply(lambda x: x['rating'])

review_df = review_df.drop(columns=['reviews'])

review_df
# Out:
#                                    product   brand  \
# 270  Baseus Eli 2i Fit Open-Ear Headphones  Baseus
# 270  Baseus Eli 2i Fit Open-Ear Headphones  Baseus
# 270  Baseus Eli 2i Fit Open-Ear Headphones  Baseus
# 270  Baseus Eli 2i Fit Open-Ear Headphones  Baseus
# 270  Baseus Eli 2i Fit Open-Ear Headphones  Baseus
# ..                                     ...     ...
# 579    Redmi Buds 6 Lite in-Ear Headphones  Xiaomi
# 579    Redmi Buds 6 Lite in-Ear Headphones  Xiaomi
# 579    Redmi Buds 6 Lite in-Ear Headphones  Xiaomi
# 579    Redmi Buds 6 Lite in-Ear Headphones  Xiaomi
# 579    Redmi Buds 6 Lite in-Ear Headphones  Xiaomi
#
#                                            review_text       review_rating
# 270  These are actually surprisingly nice. To be cl...  5.0 out of 5 stars
# 270  One of the best over the ear phones. It delive...  5.0 out of 5 stars
# 270  Got mine today. Some quick observations• Diffi...  4.0 out of 5 stars
# 270  I've had mixed experiences with Baseus earphon...  5.0 out of 5 stars
# 270  These are fine. Decent sound and battery life,...  3.0 out of 5 stars
# ..                                                 ...                 ...
# 579  The Redmi Buds 6 lite are a great low-cost opt...  5.0 out of 5 stars
# 579                     They look and work really well  5.0 out of 5 stars
# 579  I'm not an audiophile, I also don't tend to pu...  5.0 out of 5 stars
# 579  I bought a blue one but get a white one. Color...  1.0 out of 5 stars
# 579  Truth be told, this is as good or better as th...  5.0 out of 5 stars
#
# [3598 rows x 4 columns]

# %% [markdown]
# # v. Saving Cleaned Data to CSV

# %%
# Save cleaned data to CSV
df.to_csv('data_after_clean.csv', index=False)

# %%
# Save review data to CSV
review_df.to_csv('review_data.csv', index=False)
